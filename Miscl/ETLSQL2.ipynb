# %%
#* ----------------------------------------------------------------------------------
#*  Note: Options data is an input file here as both CSV as well as Scraped from
#* .    the option site of Yahoo screen!                                                                  -
#* 1. Report on all OUTPUT CSV files from prior SQL runs                            -
#* 2. Using sqlalchemy, load an ETL to SQL_PG_Admin                                 -
#* 3. Link PANDAS-PYTHON to the SQL database, that includes Stocks & Options Data.  -
#* 4. Load the data for future use                                      -
#* 5. Ensure Password used to access DB:ALEMIDEPT is not passed to github           -
#* 6. Create MPLOT Charts on some of the outputs, to provide a visual report        -
#*                                                                 -
#* -                                                        Piruz Alemi, Jan 31 2020 -
#* ----------------------------------------------------------------------------------

# %%
# SQLAlchemy
from sqlalchemy import create_engine

# %%
# . Parses a Paasword
# . Perhaps! it should be placed in a config file that is placed in .ignore
import urllib.parse
urllib.parse.quote_plus("Roshan$$0*7")
# Out:
# 'Roshan%24%240%2A7'

# %%
# import output CSV files of SQL runs into Pandas_Python program
# Note to the reader: These CSV files are output files of SQL runs under PgAdmin
import pandas as pd
import os
pd.read_csv("../ETL_Challenge/spy.csv")
# Report #1: Employees Report by Dept Name.
#            . This and other subsequents reports were originally created by Alemi
#            in SQL under PgAdmin
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-01-29  263.920013  264.549988  262.480011  263.410004  258.514801
# 1    2019-01-30  265.100006  268.519989  264.250000  267.579987  262.607300
# 2    2019-01-31  267.510010  270.470001  267.269989  269.929993  264.913605
# 3    2019-02-01  270.149994  271.200012  269.179993  270.059998  265.041229
# 4    2019-02-04  270.109985  272.029999  269.359985  271.959991  266.905884
# ..          ...         ...         ...         ...         ...         ...
# 247  2020-01-22  332.239990  332.950012  331.170013  331.339996  331.339996
# 248  2020-01-23  330.630005  332.170013  329.410004  331.720001  331.720001
# 249  2020-01-24  332.440002  332.529999  327.359985  328.769989  328.769989
# 250  2020-01-27  323.029999  325.119995  322.660004  323.500000  323.500000
# 251  2020-01-28  325.059998  327.839996  323.603790  326.880005  326.880005
#
#         Volume
# 0     66136300
# 1     92473700
# ...

# %%
pd.read_csv("../etl_Challenge/options_data.csv")
# Report #1b: List of employees and their salaries
# Out:
#           Contract Name    Bid  Strike  Last Price         Last Trade Date  \
# 0    SPY200129C00280000  47.87   280.0       42.65  2020-01-06 12:15PM EST
# 1    SPY200129C00300000  27.92   300.0       27.00   2020-01-27 3:42PM EST
# 2    SPY200129C00301000  26.93   301.0       22.96   2020-01-27 3:41PM EST
# 3    SPY200129C00302000  25.93   302.0       26.40   2020-01-10 9:37AM EST
# 4    SPY200129C00303000  24.92   303.0       23.84   2020-01-28 1:05PM EST
# ..                  ...    ...     ...         ...                     ...
# 162  SPY200131C00350000   0.00   350.0        0.01   2020-01-27 1:46PM EST
# 163  SPY200131C00352500   0.00   352.5        0.02  2019-12-30 11:08AM EST
# 164  SPY200131C00355000   0.00   355.0        0.01   2020-01-16 2:07PM EST
# 165  SPY200131C00365000      -   365.0        0.01   2020-01-30 3:51PM EST
# 166  SPY200131C00370000      -   370.0        0.01  2020-01-30 11:05PM EST
#
#     Implied Volatility                DateTime
# ...

# %%
# Path to sqlite
database_path = "http://localhost:5432/SPY"

# %% [markdown]
# * -------------------------------------------------------------------
# * sqlite://<nohostname>/<path>
#
# * where <path> is relative:
# * engine = create_engine('sqlite:///Manager.db')
# * See: https://docs.sqlalchemy.org/en/13/core/engines.html#postgresql
#
# * Unix/Mac - 4 initial slashes in total
# * engine = create_engine('sqlite:////absolute/path/to/foo.db')
# * -------------------------------------------------------------------

# %%
# Import and establish Base for which classes will be constructed 
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
# Import modules to declare columns and column data types
from sqlalchemy import Column, Integer, String, Float

# %%
import sys

# %%
# .  does connect
engine = create_engine('postgresql://postgres:Roshan2017@localhost:5432/SPY',pool_size=20,max_overflow=-1)
#connection = engine.connect()
conn = engine.connect()
# https://martin-thoma.com/configuration-files-in-python/

# %% [raw]
# drop table Stock_option

# %%
#----------------------------------------------------------------
# Create SPY class(es), with its corresponding Table
#----------------------------------------------------------------

class SPY(Base):
    __tablename__ = 'Stock_Option'
    Contract_Name = Column(String(20))
    Bid = Column(Integer, primary_key=True)
    Stocks = Column(Integer)
    Strike = Column(Integer)
    Options = Column(Integer)
    Date=Column(Integer)
    ImpliedVolatility=Column(Integer)
    ClosePrice=Column(Integer)

# %%
##
#engine = create_engine('postgresql://postgres:Roshan2017@localhost:5432/SPY',pool_size=20,max_overflow=-1)
# ---------------------------------------------------------------------------------------
###connection = engine.connect()    This was connected to SQLITE which we are not using here!#
#conn = engine.connect()
#  See: https://martin-thoma.com/configuration-files-in-python/

# %%
#!/usr/bin/env python
#import databaseconfig as cfg
#connect(cfg.mysql['host'], cfg.mysql['user'], cfg.mysql['password'])

# %%
#-------------------------------------------------
# Create Database Connection - Does Connect
# ------------------------------------------------
# Establish Connection
#engine = create_engine("sqlite:///manager.sqlite")
#conn = engine.connect()

# %%
# ----------------------------------------------------------------------------------
#  Create specific instances of SPY_Table
# . Make sure you increment the "key" as it cannot be added as a duplicate key!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ----------------------------------------------------------------------------------
table_data = SPY(Contract_Name='call-Alemi-C00009', 
                 Bid=349, 
                 Stocks=350,
                 Strike=320,
                 Options=33.5,
                 Date=20200105,
                 ImpliedVolatility=45,
                 ClosePrice= 324)

# %%
# Create Managers and possibly other tables within the database
Base.metadata.create_all(conn)

# %%
# To push the objects (Table) made and query the server we use a Session object
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
# Add "Table" to the current session
session.add(table_data)
# Commit the object to the database
session.commit()

# %%
# Query the database and collect all of the stock data in the database
query_list = session.query(SPY)
for bro in query_list:
    print(bro.Contract_Name)
    print(bro.Bid)
    print(bro.Stocks)
# Out:
# call-Alemi-C00006
# 345
# 350
# call-Alemi-C00007
# 348
# 350
# call-Alemi-C00009
# 349
# 350

# %%
#--Import Matplot lib
import numpy as np

import matplotlib
from matplotlib import style
style.use('seaborn')
import matplotlib.pyplot as plt

# %%
# .  Which Contract occurs most
# pd.read_csv("../sql_Challenge/data-1578190445297.csv")
# . The above CSV contained a histogram

# %%
#input_df = pd.read_csv("../sql_Challenge/data-1578190445297.csv", delimiter=',', names = ['last_name', 'counter'])
input_df = pd.read_csv("../etl_Challenge/options_data.csv",nrows=10)
input_df.head(10)
# Out:
#         Contract Name    Bid  Strike  Last Price         Last Trade Date  \
# 0  SPY200129C00280000  47.87   280.0       42.65  2020-01-06 12:15PM EST
# 1  SPY200129C00300000  27.92   300.0       27.00   2020-01-27 3:42PM EST
# 2  SPY200129C00301000  26.93   301.0       22.96   2020-01-27 3:41PM EST
# 3  SPY200129C00302000  25.93   302.0       26.40   2020-01-10 9:37AM EST
# 4  SPY200129C00303000  24.92   303.0       23.84   2020-01-28 1:05PM EST
# 5  SPY200129C00305000  22.95   305.0       21.44  2020-01-28 10:25AM EST
# 6  SPY200129C00308000  19.92   308.0       18.84   2020-01-24 2:58PM EST
# 7  SPY200129C00309000  18.92   309.0       15.69   2020-01-27 9:50AM EST
# 8  SPY200129C00310000  17.95   310.0       17.75  2020-01-29 10:57AM EST
# 9  SPY200129C00312000  15.93   312.0       14.56   2020-01-21 3:36PM EST
#
#   Implied Volatility                DateTime
# 0            135.16%  2020-01-06 12:15PM EST
# 1             83.20%   2020-01-27 3:42PM EST
# ...

# %%
# --------------------------------------------------------------------------
# .             This command scrapes the Options Data set and by passes the CSV!
# --------------------------------------------------------------------------
options=pd.read_html("https://finance.yahoo.com/quote/SPY/options?p=SPY")
print(options)
# Out:
# [         Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 0   SPY200203C00270000   2020-01-31 3:46PM EST   270.0       51.70  52.15
# 1   SPY200203C00275000  2020-01-03 12:36PM EST   275.0       49.01  47.15
# 2   SPY200203C00280000  2020-01-06 12:03PM EST   280.0       42.76  42.16
# 3   SPY200203C00285000  2020-01-06 12:01PM EST   285.0       37.82  37.17
# 4   SPY200203C00290000   2020-01-31 3:39PM EST   290.0       31.18  32.19
# 5   SPY200203C00296000  2020-01-30 10:26AM EST   296.0       26.25  26.21
# 6   SPY200203C00300000   2020-01-31 3:40PM EST   300.0       21.19  22.23
# 7   SPY200203C00302000  2020-01-30 11:05PM EST   302.0       20.47  20.25
# 8   SPY200203C00305000  2020-01-28 10:08AM EST   305.0       18.73  17.28
# 9   SPY200203C00307000   2020-01-03 3:50PM EST   307.0       18.45  15.31
# 10  SPY200203C00309000   2020-01-27 9:43AM EST   309.0       13.05  13.35
# 11  SPY200203C00310000   2020-01-31 4:10PM EST   310.0       12.45  12.39
# ...

# %%
options[0].head()
# Out:
#         Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 0  SPY200203C00270000   2020-01-31 3:46PM EST   270.0       51.70  52.15
# 1  SPY200203C00275000  2020-01-03 12:36PM EST   275.0       49.01  47.15
# 2  SPY200203C00280000  2020-01-06 12:03PM EST   280.0       42.76  42.16
# 3  SPY200203C00285000  2020-01-06 12:01PM EST   285.0       37.82  37.17
# 4  SPY200203C00290000   2020-01-31 3:39PM EST   290.0       31.18  32.19
#
#      Ask  Change % Change Volume Open Interest Implied Volatility
# 0  52.42  -10.11  -16.36%     80             0            113.72%
# 1  47.42    0.00        -      2             0            103.86%
# 2  42.43    0.00        -      -             0             94.43%
# 3  37.43    0.00        -      -             0             84.77%
# 4  32.44   -5.81  -15.71%      1             0             75.39%

# %%
options_df=options[0][["Contract Name","Bid","Strike","Last Price", "Last Trade Date", "Implied Volatility"]]
#Bid=options[0][["Bid"]]
#Bid
options_df.head()
# Out:
#         Contract Name    Bid  Strike  Last Price         Last Trade Date  \
# 0  SPY200203C00270000  52.15   270.0       51.70   2020-01-31 3:46PM EST
# 1  SPY200203C00275000  47.15   275.0       49.01  2020-01-03 12:36PM EST
# 2  SPY200203C00280000  42.16   280.0       42.76  2020-01-06 12:03PM EST
# 3  SPY200203C00285000  37.17   285.0       37.82  2020-01-06 12:01PM EST
# 4  SPY200203C00290000  32.19   290.0       31.18   2020-01-31 3:39PM EST
#
#   Implied Volatility
# 0            113.72%
# 1            103.86%
# 2             94.43%
# 3             84.77%
# 4             75.39%

# %%
options_df["DateTime"] = options_df["Last Trade Date"]
#options_df["DateTime"] = options_df["Last Trade Date"]
DateTime.head()
# Out:
# /Users/piruzalemi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-42945c8abf1b> in <module>
#       1 options_df["DateTime"] = options_df["Last Trade Date"]
#       2 #options_df["DateTime"] = options_df["Last Trade Date"]
# ----> 3 DateTime.head()
#
# NameError: name 'DateTime' is not defined

# %%
#df = options_df.DateTime.str.split(expand=True)   
#df.columns = ['Date', 'Time', 'place']

# %%
#options_df = options_df.DateTime.str.split(expand=True)   
#options_df

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
Options=pd.merge(options_df, df, on='Date', how='left')
Options
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-d767982b1109> in <module>
# ----> 1 Options=pd.merge(options_df, df, on='Date', how='left')
#       2 Options
#
# NameError: name 'df' is not defined

# %%
stocks=pd.read_csv("../ETL_Challenge/spy.csv")
stocks.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2019-01-29  263.920013  264.549988  262.480011  263.410004  258.514801
# 1  2019-01-30  265.100006  268.519989  264.250000  267.579987  262.607300
# 2  2019-01-31  267.510010  270.470001  267.269989  269.929993  264.913605
# 3  2019-02-01  270.149994  271.200012  269.179993  270.059998  265.041229
# 4  2019-02-04  270.109985  272.029999  269.359985  271.959991  266.905884
#
#       Volume
# 0   66136300
# 1   92473700
# 2  104012100
# 3   85782500
# 4   60744800

# %%
options_df = options_df.drop_duplicates(subset=['Date'], keep='first')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-19024969e6db> in <module>
# ----> 1 options_df = options_df.drop_duplicates(subset=['Date'], keep='first')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace)
#    4892
#    4893         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 4894         duplicated = self.duplicated(subset, keep=keep)
#    4895
#    4896         if inplace:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    4949         diff = Index(subset).difference(self.columns)
#    4950         if not diff.empty:
# -> 4951             raise KeyError(diff)
#    4952
#    4953         vals = (col.values for name, col in self.items() if name in subset)
#
# KeyError: Index(['Date'], dtype='object')

# %%
stockOption=pd.merge(options_df, stocks, on='Date', how='left')
stockOption
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-bb2632e70462> in <module>
# ----> 1 stockOption=pd.merge(options_df, stocks, on='Date', how='left')
#       2 stockOption
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     624             self.right_join_keys,
#     625             self.join_names,
# --> 626         ) = self._get_merge_keys()
#     627
# ...

# %%
options_df['Date'] = df["Date"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-23d9ef8218fc> in <module>
# ----> 1 options_df['Date'] = df["Date"]
#
# NameError: name 'df' is not defined

# %%
# Set x axis and tick locations
x_axis = np.arange(len(input_df))
tick_locations = [value for value in x_axis]
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, input_df["count"], color='b', alpha=0.5, align="center")
plt.xticks(tick_locations, input_df["Contract_name"], rotation="vertical")
# Set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(215, max(input_df["count"])+10)
# Set a Title and labels
plt.title("Top 10 Repeated Frequencies of Last-Names in Employees file")
plt.xlabel("Last Names")
plt.ylabel("Frequency of occurance")
plt.tight_layout()
plt.savefig("../sql_challenge/lastName_Freq.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'count'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-81c9a5598b19> in <module>
# ...

# %%
options_df.head()
# Out:
#         Contract Name    Bid  Strike  Last Price         Last Trade Date  \
# 0  SPY200203C00270000  52.15   270.0       51.70   2020-01-31 3:46PM EST
# 1  SPY200203C00275000  47.15   275.0       49.01  2020-01-03 12:36PM EST
# 2  SPY200203C00280000  42.16   280.0       42.76  2020-01-06 12:03PM EST
# 3  SPY200203C00285000  37.17   285.0       37.82  2020-01-06 12:01PM EST
# 4  SPY200203C00290000  32.19   290.0       31.18   2020-01-31 3:39PM EST
#
#   Implied Volatility                DateTime
# 0            113.72%   2020-01-31 3:46PM EST
# 1            103.86%  2020-01-03 12:36PM EST
# 2             94.43%  2020-01-06 12:03PM EST
# 3             84.77%  2020-01-06 12:01PM EST
# 4             75.39%   2020-01-31 3:39PM EST

# %%
#plt.tight_layout()
#plt.savefig("../sql_challenge/lastName_Freq.png")
#plt.show()
